# %% [markdown]
# # Example 1: Preprocessing Workflow
#
# This is meant as a very simple example for a preprocessing workflow. In this workflow we will conduct the following steps:
#
# 1. Motion correction of functional images with FSL's MCFLIRT
# 2. Coregistration of functional images to anatomical images (according to FSL's FEAT pipeline)
# 3. Smoothing of coregistrated functional images with FWHM set to 4mm and 8mm
# 4. Artifact Detection in functional images (to detect outlier volumes)

# %% [markdown]
# For every subject we have one anatomical T1w and 5 functional images. As a short recap, the image properties of the anatomy and the **fingerfootlips** functional image are:

# %% [markdown]
# **So, let's start!**

# %% [markdown]
# ## Imports
#
# First, let's import all modules we later will be needing.

# %%
import platform
print(platform.python_version())

from nipype.interfaces.matlab import MatlabCommand


# %matplotlib inline
from os.path import join as opj
import os
import json
from nipype.interfaces.fsl import (BET, ExtractROI, FAST, FLIRT, ImageMaths,
                                   MCFLIRT, SliceTimer, Threshold)
from nipype.interfaces.spm import Smooth
from nipype.interfaces.utility import IdentityInterface
from nipype.interfaces.io import SelectFiles, DataSink
from nipype.algorithms.rapidart import ArtifactDetect
from nipype.pipeline.engine import Workflow, Node
# Out:
# 3.6.2

# %% [markdown]
# ## Experiment parameters
#
# It's always a good idea to specify all parameters that might change between experiments at the beginning of your script. We will use one functional image for fingerfootlips task for ten subjects.

# %%
model = 'self_other'

experiment_dir = opj('/output', model)

output_dir = 'datasink'
working_dir = 'workingdir'

# list of subject identifiers
subject_list = ['sub-222', 'sub-256', 'sub-270']

# list of session identifiers
task_list = ['emp']

# Smoothing widths to apply
fwhm = [4, 8]

# TR of functional images
with open('/data/task-emp_bold.json', 'rt') as fp:
    task_info = json.load(fp)
TR = task_info['RepetitionTime']

print(TR)


# Isometric resample of functional images to voxel size (in mm)
iso_size = 4
# Out:
# 2.0

# %% [markdown]
# ## Specify Nodes for the main workflow
#
# Initiate all the different interfaces (represented as nodes) that you want to use in your workflow.

# %%
# ExtractROI - skip dummy scans
extract = Node(ExtractROI(t_min=4, t_size=-1),
               output_type='NIFTI',
               name="extract")

# MCFLIRT - motion correction
mcflirt = Node(MCFLIRT(mean_vol=True,
                       save_plots=True,
                       output_type='NIFTI'),
               name="mcflirt")

# SliceTimer - correct for slice wise acquisition
slicetimer = Node(SliceTimer(index_dir=False,
                             interleaved=True,
                             output_type='NIFTI',
                             time_repetition=TR),
                  name="slicetimer")

# Smooth - image smoothing
smooth = Node(Smooth(), name="smooth")
smooth.iterables = ("fwhm", fwhm)

# Artifact Detection - determines outliers in functional images
art = Node(ArtifactDetect(norm_threshold=2,
                          zintensity_threshold=3,
                          mask_type='spm_global',
                          parameter_source='FSL',
                          use_differences=[True, False],
                          plot_type='svg'),
           name="art")

# %% [markdown]
# ## Coregistration Workflow
#
# Initiate a workflow that coregistrates the functional images to the anatomical image (according to FSL's FEAT pipeline).

# %%
# BET - Skullstrip anatomical Image
bet_anat = Node(BET(frac=0.5,
                    robust=True,
                    output_type='NIFTI_GZ'),
                name="bet_anat")

# FAST - Image Segmentation
segmentation = Node(FAST(output_type='NIFTI_GZ'),
                name="segmentation")

# Select WM segmentation file from segmentation output
def get_wm(files):
    return files[-1]

# Threshold - Threshold WM probability image
threshold = Node(Threshold(thresh=0.5,
                           args='-bin',
                           output_type='NIFTI_GZ'),
                name="threshold")

# FLIRT - pre-alignment of functional images to anatomical images
coreg_pre = Node(FLIRT(dof=6, output_type='NIFTI_GZ'),
                 name="coreg_pre")

# FLIRT - coregistration of functional images to anatomical images with BBR
coreg_bbr = Node(FLIRT(dof=6,
                       cost='bbr',
                       schedule=opj(os.getenv('FSLDIR'),
                                    'etc/flirtsch/bbr.sch'),
                       output_type='NIFTI_GZ'),
                 name="coreg_bbr")

# Apply coregistration warp to functional images
applywarp = Node(FLIRT(interp='spline',
                       apply_isoxfm=iso_size,
                       output_type='NIFTI'),
                 name="applywarp")

# Apply coregistration warp to mean file
applywarp_mean = Node(FLIRT(interp='spline',
                            apply_isoxfm=iso_size,
                            output_type='NIFTI_GZ'),
                 name="applywarp_mean")

# Create a coregistration workflow
coregwf = Workflow(name='coregwf')
coregwf.base_dir = opj(experiment_dir, working_dir)

# Connect all components of the coregistration workflow
coregwf.connect([(bet_anat, segmentation, [('out_file', 'in_files')]),
                 (segmentation, threshold, [(('partial_volume_files', get_wm),
                                             'in_file')]),
                 (bet_anat, coreg_pre, [('out_file', 'reference')]),
                 (threshold, coreg_bbr, [('out_file', 'wm_seg')]),
                 (coreg_pre, coreg_bbr, [('out_matrix_file', 'in_matrix_file')]),
                 (coreg_bbr, applywarp, [('out_matrix_file', 'in_matrix_file')]),
                 (bet_anat, applywarp, [('out_file', 'reference')]),
                 (coreg_bbr, applywarp_mean, [('out_matrix_file', 'in_matrix_file')]),
                 (bet_anat, applywarp_mean, [('out_file', 'reference')]),
                 ])

# %% [markdown]
# ## Specify input & output stream
#
# Specify where the input data can be found & where and how to save the output data.

# %%
# Infosource - a function free node to iterate over the list of subject names
infosource = Node(IdentityInterface(fields=['subject_id', 'task_name']),
                  name="infosource")
infosource.iterables = [('subject_id', subject_list),
                        ('task_name', task_list)]

# SelectFiles - to grab the data (alternativ to DataGrabber)
anat_file = opj( 'derivatives', 'fmriprep', '{subject_id}', 'anat', '{subject_id}_T1w_preproc.nii.gz')
func_file = opj( '{subject_id}','func',
                '{subject_id}_task-{task_name}_run-01_bold.nii.gz')

templates = {'anat': anat_file,
             'func': func_file}

selectfiles = Node(SelectFiles(templates,
                               base_directory='/data'),
                   name="selectfiles")

# Datasink - creates output folder for important outputs
datasink = Node(DataSink(base_directory=experiment_dir,
                         container=output_dir),
                name="datasink")

## Use the following DataSink output substitutions
substitutions = [('_subject_id_', ''),
                 ('_task_name_', '/task-'),
                 ('_fwhm_', 'fwhm-'),
                 ('_roi', ''),
                 ('_mcf', ''),
                 ('_st', ''),
                 ('_flirt', ''),
                 ('.nii_mean_reg', '_mean'),
                 ('.nii.par', '.par'),
                 ]
subjFolders = [('fwhm-%s/' % f, 'fwhm-%s_' % f) for f in fwhm]
substitutions.extend(subjFolders)
datasink.inputs.substitutions = substitutions

# %% [markdown]
# ## Specify Workflow
#
# Create a workflow and connect the interface nodes and the I/O stream to each other.

# %%
# Create a preprocessing workflow
preproc = Workflow(name='preproc')
preproc.base_dir = opj(experiment_dir, working_dir)

# Connect all components of the preprocessing workflow
preproc.connect([(infosource, selectfiles, [('subject_id', 'subject_id'),
                                            ('task_name', 'task_name')]),
                 (selectfiles, extract, [('func', 'in_file')]),
                 (extract, mcflirt, [('roi_file', 'in_file')]),
                 (mcflirt, slicetimer, [('out_file', 'in_file')]),

                 (selectfiles, coregwf, [('anat', 'bet_anat.in_file'),
                                         ('anat', 'coreg_bbr.reference')]),
                 (mcflirt, coregwf, [('mean_img', 'coreg_pre.in_file'),
                                     ('mean_img', 'coreg_bbr.in_file'),
                                     ('mean_img', 'applywarp_mean.in_file')]),
                 (slicetimer, coregwf, [('slice_time_corrected_file', 'applywarp.in_file')]),
                 
                 (coregwf, smooth, [('applywarp.out_file', 'in_files')]),

                 (mcflirt, datasink, [('par_file', 'preproc.@par')]),
                 (smooth, datasink, [('smoothed_files', 'preproc.@smooth')]),
                 (coregwf, datasink, [('applywarp_mean.out_file', 'preproc.@mean')]),

                 (coregwf, art, [('applywarp.out_file', 'realigned_files')]),
                 (mcflirt, art, [('par_file', 'realignment_parameters')]),

                 (coregwf, datasink, [('coreg_bbr.out_matrix_file', 'preproc.@mat_file'),
                                      ('bet_anat.out_file', 'preproc.@brain')]),
                 (art, datasink, [('outlier_files', 'preproc.@outlier_files'),
                                  ('plot_files', 'preproc.@plot_files')]),
                 ])

# %% [markdown]
# ## Visualize the workflow
#
# It always helps to visualize your workflow.

# %%
# Create preproc output graph
preproc.write_graph(graph2use='colored', format='png', simple_form=True)

# Visualize the graph
from IPython.display import Image
#Image(filename=opj(preproc.base_dir, 'preproc', 'graph.dot.png'))
# Out:
# 170922-23:13:08,11 workflow INFO:
# 	 Generated workflow graph: /output/workingdir/preproc/graph.dot.png (graph2use=colored, simple_form=True).

# %%
# Visualize the detailed graph
preproc.write_graph(graph2use='flat', format='png', simple_form=True)
Image(filename=opj(preproc.base_dir, 'preproc', 'graph_detailed.dot.png'))
# Out:
# 170922-23:13:08,547 workflow INFO:
# 	 Generated workflow graph: /output/workingdir/preproc/graph.dot.png (graph2use=flat, simple_form=True).

# %% [markdown]
# ##  Run the Workflow
#
# Now that everything is ready, we can run the preprocessing workflow. Change ``n_procs`` to the number of jobs/cores you want to use. **Note** that if  you're using a Docker container and FLIRT fails to run without any good reason, you might need to change memory settings in the Docker preferences (6 GB should be enough for this workflow).

# %%
preproc.run('MultiProc', plugin_args={'n_procs': 4})
# Out:
# 170922-18:54:44,341 workflow INFO:
# 	 Workflow preproc settings: ['check', 'execution', 'logging']
# 170922-18:54:44,422 workflow INFO:
# 	 Running in parallel.
# 170922-18:54:44,427 workflow INFO:
# 	 Executing: selectfiles.b2 ID: 0
# 170922-18:54:44,436 workflow INFO:
# 	 Executing: selectfiles.b1 ID: 16
# 170922-18:54:44,440 workflow INFO:
# 	 Executing node selectfiles.b2 in dir: /output/workingdir/preproc/_subject_id_sub-270_task_name_emp/selectfiles170922-18:54:44,448 workflow INFO:
# 	 Executing: selectfiles.b0 ID: 32
#
# 170922-18:54:44,452 workflow INFO:
# 	 Executing node selectfiles.b1 in dir: /output/workingdir/preproc/_subject_id_sub-256_task_name_emp/selectfiles
# 170922-18:54:44,464 workflow INFO:
# 	 Executing node selectfiles.b0 in dir: /output/workingdir/preproc/_subject_id_sub-222_task_name_emp/selectfiles
# 170922-18:54:44,605 workflow INFO:
# 	 [Job finished] jobname: selectfiles.b2 jobid: 0
# 170922-18:54:44,614 workflow INFO:
# 	 Executing: extract.b2 ID: 1
# 170922-18:54:44,633 workflow INFO:
# 	 Executing: bet_anat.b2 ID: 4
# 170922-18:54:44,638 workflow INFO:
# 	 Executing node extract.b2 in dir: /output/workingdir/preproc/_subject_id_sub-270_task_name_emp/extract
# 170922-18:54:44,677 workflow INFO:
# 	 [Job finished] jobname: selectfiles.b1 jobid: 16
# 170922-18:54:44,685 workflow INFO:
# 	 Executing node bet_anat.b2 in dir: /output/workingdir/preproc/coregwf/_subject_id_sub-270_task_name_emp/bet_anat
# 170922-18:54:44,756 workflow INFO:
# 	 [Job finished] jobname: selectfiles.b0 jobid: 32
# 170922-18:54:44,762 workflow INFO:
# 	 Executing: extract.b1 ID: 17
# 170922-18:54:44,783 workflow INFO:
# 	 Executing: bet_anat.b1 ID: 20
# 170922-18:54:44,773 workflow INFO:
# 	 Running: fslroi /data/sub-270/func/sub-270_task-emp_run-01_bold.nii.gz /output/workingdir/preproc/_subject_id_sub-270_task_name_emp/extract/sub-270_task-emp_run-01_bold_roi.nii.gz 4 -1170922-18:54:44,786 workflow INFO:
# 	 Executing node extract.b1 in dir: /output/workingdir/preproc/_subject_id_sub-256_task_name_emp/extract170922-18:54:44,783 workflow INFO:
# 	 Running: bet /data/derivatives/fmriprep/sub-270/anat/sub-270_T1w_preproc.nii.gz /output/workingdir/preproc/coregwf/_subject_id_sub-270_task_name_emp/bet_anat/sub-270_T1w_preproc_brain.nii.gz -f 0.50 -R
#
#
# 170922-18:54:44,809 workflow INFO:
# 	 Executing node bet_anat.b1 in dir: /output/workingdir/preproc/coregwf/_subject_id_sub-256_task_name_emp/bet_anat
# 170922-18:54:44,834 workflow INFO:
# 	 Running: fslroi /data/sub-256/func/sub-256_task-emp_run-01_bold.nii.gz /output/workingdir/preproc/_subject_id_sub-256_task_name_emp/extract/sub-256_task-emp_run-01_bold_roi.nii.gz 4 -1
# 170922-18:54:44,883 workflow INFO:
# 	 Running: bet /data/derivatives/fmriprep/sub-256/anat/sub-256_T1w_preproc.nii.gz /output/workingdir/preproc/coregwf/_subject_id_sub-256_task_name_emp/bet_anat/sub-256_T1w_preproc_brain.nii.gz -f 0.50 -R
# 170922-18:55:02,755 workflow INFO:
# 	 [Job finished] jobname: bet_anat.b1 jobid: 20
# 170922-18:55:02,759 workflow INFO:
# 	 Executing: segmentation.b1 ID: 21
# 170922-18:55:02,784 workflow INFO:
# 	 Executing node segmentation.b1 in dir: /output/workingdir/preproc/coregwf/_subject_id_sub-256_task_name_emp/segmentation
# 170922-18:55:02,939 workflow INFO:
# 	 Running: fast -S 1 /output/workingdir/preproc/coregwf/_subject_id_sub-256_task_name_emp/segmentation/sub-256_T1w_preproc_brain.nii.gz
# 170922-18:55:02,999 workflow INFO:
# 	 [Job finished] jobname: bet_anat.b2 jobid: 4
# 170922-18:55:03,3 workflow INFO:
# 	 Executing: segmentation.b2 ID: 5
# 170922-18:55:03,17 workflow INFO:
# 	 Executing node segmentation.b2 in dir: /output/workingdir/preproc/coregwf/_subject_id_sub-270_task_name_emp/segmentation
# 170922-18:55:03,85 workflow INFO:
# 	 Running: fast -S 1 /output/workingdir/preproc/coregwf/_subject_id_sub-270_task_name_emp/segmentation/sub-270_T1w_preproc_brain.nii.gz
# 170922-18:55:15,254 workflow INFO:
# 	 [Job finished] jobname: extract.b2 jobid: 1
# 170922-18:55:15,257 workflow INFO:
# 	 Executing: mcflirt.b2 ID: 2
# 170922-18:55:15,267 workflow INFO:
# 	 Executing node mcflirt.b2 in dir: /output/workingdir/preproc/_subject_id_sub-270_task_name_emp/mcflirt
# 170922-18:55:15,321 workflow INFO:
# 	 Running: mcflirt -in /output/workingdir/preproc/_subject_id_sub-270_task_name_emp/extract/sub-270_task-emp_run-01_bold_roi.nii.gz -meanvol -out /output/workingdir/preproc/_subject_id_sub-270_task_name_emp/mcflirt/sub-270_task-emp_run-01_bold_roi_mcf.nii -plots
# 170922-18:55:16,588 workflow INFO:
# 	 [Job finished] jobname: extract.b1 jobid: 17
# 170922-18:55:16,593 workflow INFO:
# 	 Executing: mcflirt.b1 ID: 18
# 170922-18:55:16,608 workflow INFO:
# 	 Executing node mcflirt.b1 in dir: /output/workingdir/preproc/_subject_id_sub-256_task_name_emp/mcflirt
# 170922-18:55:16,672 workflow INFO:
# 	 Running: mcflirt -in /output/workingdir/preproc/_subject_id_sub-256_task_name_emp/extract/sub-256_task-emp_run-01_bold_roi.nii.gz -meanvol -out /output/workingdir/preproc/_subject_id_sub-256_task_name_emp/mcflirt/sub-256_task-emp_run-01_bold_roi_mcf.nii -plots
# 170922-18:57:52,792 workflow INFO:
# 	 [Job finished] jobname: mcflirt.b2 jobid: 2
# 170922-18:57:52,795 workflow INFO:
# 	 Executing: slicetimer.b2 ID: 3
# 170922-18:57:52,807 workflow INFO:
# 	 Executing node slicetimer.b2 in dir: /output/workingdir/preproc/_subject_id_sub-270_task_name_emp/slicetimer
# 170922-18:57:52,894 workflow INFO:
# 	 Running: slicetimer --in=/output/workingdir/preproc/_subject_id_sub-270_task_name_emp/mcflirt/sub-270_task-emp_run-01_bold_roi_mcf.nii --odd --out=/output/workingdir/preproc/_subject_id_sub-270_task_name_emp/slicetimer/sub-270_task-emp_run-01_bold_roi_mcf_st.nii --repeat=2.000000
# 170922-18:57:57,536 workflow INFO:
# 	 [Job finished] jobname: mcflirt.b1 jobid: 18
# 170922-18:57:57,540 workflow INFO:
# 	 Executing: coreg_pre.b2 ID: 7
# 170922-18:57:57,558 workflow INFO:
# 	 Executing node coreg_pre.b2 in dir: /output/workingdir/preproc/coregwf/_subject_id_sub-270_task_name_emp/coreg_pre
# 170922-18:57:57,637 workflow INFO:
# 	 Running: flirt -in /output/workingdir/preproc/_subject_id_sub-270_task_name_emp/mcflirt/sub-270_task-emp_run-01_bold_roi_mcf.nii_mean_reg.nii -ref /output/workingdir/preproc/coregwf/_subject_id_sub-270_task_name_emp/bet_anat/sub-270_T1w_preproc_brain.nii.gz -out sub-270_task-emp_run-01_bold_roi_mcf.nii_mean_reg_flirt.nii.gz -omat sub-270_task-emp_run-01_bold_roi_mcf.nii_mean_reg_flirt.mat -dof 6
# 170922-18:58:11,69 workflow INFO:
# 	 [Job finished] jobname: coreg_pre.b2 jobid: 7
# 170922-18:58:11,72 workflow INFO:
# 	 Executing: slicetimer.b1 ID: 19
# 170922-18:58:11,81 workflow INFO:
# 	 Executing node slicetimer.b1 in dir: /output/workingdir/preproc/_subject_id_sub-256_task_name_emp/slicetimer
# 170922-18:58:11,119 workflow INFO:
# 	 Running: slicetimer --in=/output/workingdir/preproc/_subject_id_sub-256_task_name_emp/mcflirt/sub-256_task-emp_run-01_bold_roi_mcf.nii --odd --out=/output/workingdir/preproc/_subject_id_sub-256_task_name_emp/slicetimer/sub-256_task-emp_run-01_bold_roi_mcf_st.nii --repeat=2.000000
# 170922-18:58:22,549 workflow INFO:
# 	 [Job finished] jobname: slicetimer.b2 jobid: 3
# 170922-18:58:22,552 workflow INFO:
# 	 Executing: coreg_pre.b1 ID: 23
# 170922-18:58:22,576 workflow INFO:
# 	 Executing node coreg_pre.b1 in dir: /output/workingdir/preproc/coregwf/_subject_id_sub-256_task_name_emp/coreg_pre
# 170922-18:58:22,629 workflow INFO:
# 	 Running: flirt -in /output/workingdir/preproc/_subject_id_sub-256_task_name_emp/mcflirt/sub-256_task-emp_run-01_bold_roi_mcf.nii_mean_reg.nii -ref /output/workingdir/preproc/coregwf/_subject_id_sub-256_task_name_emp/bet_anat/sub-256_T1w_preproc_brain.nii.gz -out sub-256_task-emp_run-01_bold_roi_mcf.nii_mean_reg_flirt.nii.gz -omat sub-256_task-emp_run-01_bold_roi_mcf.nii_mean_reg_flirt.mat -dof 6
# 170922-18:58:36,66 workflow INFO:
# 	 [Job finished] jobname: coreg_pre.b1 jobid: 23
# 170922-18:58:36,69 workflow INFO:
# 	 Executing: extract.b0 ID: 33
# 170922-18:58:36,79 workflow INFO:
# 	 Executing node extract.b0 in dir: /output/workingdir/preproc/_subject_id_sub-222_task_name_emp/extract
# 170922-18:58:36,125 workflow INFO:
# 	 Running: fslroi /data/sub-222/func/sub-222_task-emp_run-01_bold.nii.gz /output/workingdir/preproc/_subject_id_sub-222_task_name_emp/extract/sub-222_task-emp_run-01_bold_roi.nii.gz 4 -1
# 170922-18:58:40,470 workflow INFO:
# 	 [Job finished] jobname: slicetimer.b1 jobid: 19
# 170922-18:58:40,473 workflow INFO:
# 	 Executing: bet_anat.b0 ID: 36
# 170922-18:58:40,485 workflow INFO:
# 	 Executing node bet_anat.b0 in dir: /output/workingdir/preproc/coregwf/_subject_id_sub-222_task_name_emp/bet_anat
# 170922-18:58:40,535 workflow INFO:
# 	 Running: bet /data/derivatives/fmriprep/sub-222/anat/sub-222_T1w_preproc.nii.gz /output/workingdir/preproc/coregwf/_subject_id_sub-222_task_name_emp/bet_anat/sub-222_T1w_preproc_brain.nii.gz -f 0.50 -R
# 170922-18:58:56,643 workflow INFO:
# 	 [Job finished] jobname: bet_anat.b0 jobid: 36
# 170922-18:58:56,646 workflow INFO:
# 	 Executing: segmentation.b0 ID: 37
# 170922-18:58:56,657 workflow INFO:
# 	 Executing node segmentation.b0 in dir: /output/workingdir/preproc/coregwf/_subject_id_sub-222_task_name_emp/segmentation
# 170922-18:58:56,704 workflow INFO:
# 	 Running: fast -S 1 /output/workingdir/preproc/coregwf/_subject_id_sub-222_task_name_emp/segmentation/sub-222_T1w_preproc_brain.nii.gz
# 170922-18:59:05,750 workflow INFO:
# 	 [Job finished] jobname: extract.b0 jobid: 33
# 170922-18:59:05,753 workflow INFO:
# 	 Executing: mcflirt.b0 ID: 34
# 170922-18:59:05,765 workflow INFO:
# 	 Executing node mcflirt.b0 in dir: /output/workingdir/preproc/_subject_id_sub-222_task_name_emp/mcflirt
# 170922-18:59:05,813 workflow INFO:
# 	 Running: mcflirt -in /output/workingdir/preproc/_subject_id_sub-222_task_name_emp/extract/sub-222_task-emp_run-01_bold_roi.nii.gz -meanvol -out /output/workingdir/preproc/_subject_id_sub-222_task_name_emp/mcflirt/sub-222_task-emp_run-01_bold_roi_mcf.nii -plots
# 170922-19:02:05,921 workflow INFO:
# 	 [Job finished] jobname: mcflirt.b0 jobid: 34
# 170922-19:02:05,925 workflow INFO:
# 	 Executing: slicetimer.b0 ID: 35
# 170922-19:02:05,939 workflow INFO:
# 	 Executing node slicetimer.b0 in dir: /output/workingdir/preproc/_subject_id_sub-222_task_name_emp/slicetimer
# 170922-19:02:05,980 workflow INFO:
# 	 Running: slicetimer --in=/output/workingdir/preproc/_subject_id_sub-222_task_name_emp/mcflirt/sub-222_task-emp_run-01_bold_roi_mcf.nii --odd --out=/output/workingdir/preproc/_subject_id_sub-222_task_name_emp/slicetimer/sub-222_task-emp_run-01_bold_roi_mcf_st.nii --repeat=2.000000
# 170922-19:02:34,987 workflow INFO:
# 	 [Job finished] jobname: slicetimer.b0 jobid: 35
# 170922-19:02:34,990 workflow INFO:
# 	 Executing: coreg_pre.b0 ID: 39
# 170922-19:02:35,15 workflow INFO:
# 	 Executing node coreg_pre.b0 in dir: /output/workingdir/preproc/coregwf/_subject_id_sub-222_task_name_emp/coreg_pre
# 170922-19:02:35,68 workflow INFO:
# 	 Running: flirt -in /output/workingdir/preproc/_subject_id_sub-222_task_name_emp/mcflirt/sub-222_task-emp_run-01_bold_roi_mcf.nii_mean_reg.nii -ref /output/workingdir/preproc/coregwf/_subject_id_sub-222_task_name_emp/bet_anat/sub-222_T1w_preproc_brain.nii.gz -out sub-222_task-emp_run-01_bold_roi_mcf.nii_mean_reg_flirt.nii.gz -omat sub-222_task-emp_run-01_bold_roi_mcf.nii_mean_reg_flirt.mat -dof 6
# 170922-19:02:49,225 workflow INFO:
# 	 [Job finished] jobname: coreg_pre.b0 jobid: 39
# 170922-19:03:17,43 workflow INFO:
# 	 [Job finished] jobname: segmentation.b2 jobid: 5
# 170922-19:03:17,46 workflow INFO:
# 	 Executing: threshold.b2 ID: 6
# 170922-19:03:17,62 workflow INFO:
# 	 Executing node threshold.b2 in dir: /output/workingdir/preproc/coregwf/_subject_id_sub-270_task_name_emp/threshold
# 170922-19:03:17,106 workflow INFO:
# 	 Running: fslmaths /output/workingdir/preproc/coregwf/_subject_id_sub-270_task_name_emp/segmentation/sub-270_T1w_preproc_brain_pve_2.nii.gz -thr 0.5000000000 -bin /output/workingdir/preproc/coregwf/_subject_id_sub-270_task_name_emp/threshold/sub-270_T1w_preproc_brain_pve_2_thresh.nii.gz
# 170922-19:03:18,483 workflow INFO:
# 	 [Job finished] jobname: segmentation.b1 jobid: 21
# 170922-19:03:18,486 workflow INFO:
# 	 Executing: threshold.b1 ID: 22
# 170922-19:03:18,501 workflow INFO:
# 	 Executing node threshold.b1 in dir: /output/workingdir/preproc/coregwf/_subject_id_sub-256_task_name_emp/threshold
# 170922-19:03:18,545 workflow INFO:
# 	 Running: fslmaths /output/workingdir/preproc/coregwf/_subject_id_sub-256_task_name_emp/segmentation/sub-256_T1w_preproc_brain_pve_2.nii.gz -thr 0.5000000000 -bin /output/workingdir/preproc/coregwf/_subject_id_sub-256_task_name_emp/threshold/sub-256_T1w_preproc_brain_pve_2_thresh.nii.gz
# 170922-19:03:18,685 workflow INFO:
# 	 [Job finished] jobname: threshold.b2 jobid: 6
# 170922-19:03:18,689 workflow INFO:
# 	 Executing: coreg_bbr.b2 ID: 8
# 170922-19:03:18,727 workflow INFO:
# 	 Executing node coreg_bbr.b2 in dir: /output/workingdir/preproc/coregwf/_subject_id_sub-270_task_name_emp/coreg_bbr
# 170922-19:03:18,774 workflow INFO:
# 	 Running: flirt -in /output/workingdir/preproc/_subject_id_sub-270_task_name_emp/mcflirt/sub-270_task-emp_run-01_bold_roi_mcf.nii_mean_reg.nii -ref /data/derivatives/fmriprep/sub-270/anat/sub-270_T1w_preproc.nii.gz -out sub-270_task-emp_run-01_bold_roi_mcf.nii_mean_reg_flirt.nii.gz -omat sub-270_task-emp_run-01_bold_roi_mcf.nii_mean_reg_flirt.mat -cost bbr -dof 6 -init /output/workingdir/preproc/coregwf/_subject_id_sub-270_task_name_emp/coreg_pre/sub-270_task-emp_run-01_bold_roi_mcf.nii_mean_reg_flirt.mat -schedule /usr/share/fsl/5.0/etc/flirtsch/bbr.sch -wmseg /output/workingdir/preproc/coregwf/_subject_id_sub-270_task_name_emp/threshold/sub-270_T1w_preproc_brain_pve_2_thresh.nii.gz
# 170922-19:03:20,409 workflow INFO:
# 	 [Job finished] jobname: threshold.b1 jobid: 22
# 170922-19:03:20,412 workflow INFO:
# 	 Executing: coreg_bbr.b1 ID: 24
# 170922-19:03:20,444 workflow INFO:
# 	 Executing node coreg_bbr.b1 in dir: /output/workingdir/preproc/coregwf/_subject_id_sub-256_task_name_emp/coreg_bbr
# 170922-19:03:20,496 workflow INFO:
# 	 Running: flirt -in /output/workingdir/preproc/_subject_id_sub-256_task_name_emp/mcflirt/sub-256_task-emp_run-01_bold_roi_mcf.nii_mean_reg.nii -ref /data/derivatives/fmriprep/sub-256/anat/sub-256_T1w_preproc.nii.gz -out sub-256_task-emp_run-01_bold_roi_mcf.nii_mean_reg_flirt.nii.gz -omat sub-256_task-emp_run-01_bold_roi_mcf.nii_mean_reg_flirt.mat -cost bbr -dof 6 -init /output/workingdir/preproc/coregwf/_subject_id_sub-256_task_name_emp/coreg_pre/sub-256_task-emp_run-01_bold_roi_mcf.nii_mean_reg_flirt.mat -schedule /usr/share/fsl/5.0/etc/flirtsch/bbr.sch -wmseg /output/workingdir/preproc/coregwf/_subject_id_sub-256_task_name_emp/threshold/sub-256_T1w_preproc_brain_pve_2_thresh.nii.gz
# 170922-19:06:05,416 workflow INFO:
# 	 [Job finished] jobname: segmentation.b0 jobid: 37
# 170922-19:06:05,419 workflow INFO:
# 	 Executing: threshold.b0 ID: 38
# 170922-19:06:05,435 workflow INFO:
# 	 Executing node threshold.b0 in dir: /output/workingdir/preproc/coregwf/_subject_id_sub-222_task_name_emp/threshold
# 170922-19:06:05,486 workflow INFO:
# 	 Running: fslmaths /output/workingdir/preproc/coregwf/_subject_id_sub-222_task_name_emp/segmentation/sub-222_T1w_preproc_brain_pve_2.nii.gz -thr 0.5000000000 -bin /output/workingdir/preproc/coregwf/_subject_id_sub-222_task_name_emp/threshold/sub-222_T1w_preproc_brain_pve_2_thresh.nii.gz
# 170922-19:06:07,352 workflow INFO:
# 	 [Job finished] jobname: threshold.b0 jobid: 38
# 170922-19:06:07,356 workflow INFO:
# 	 Executing: coreg_bbr.b0 ID: 40
# 170922-19:06:07,386 workflow INFO:
# 	 Executing node coreg_bbr.b0 in dir: /output/workingdir/preproc/coregwf/_subject_id_sub-222_task_name_emp/coreg_bbr
# 170922-19:06:07,445 workflow INFO:
# 	 Running: flirt -in /output/workingdir/preproc/_subject_id_sub-222_task_name_emp/mcflirt/sub-222_task-emp_run-01_bold_roi_mcf.nii_mean_reg.nii -ref /data/derivatives/fmriprep/sub-222/anat/sub-222_T1w_preproc.nii.gz -out sub-222_task-emp_run-01_bold_roi_mcf.nii_mean_reg_flirt.nii.gz -omat sub-222_task-emp_run-01_bold_roi_mcf.nii_mean_reg_flirt.mat -cost bbr -dof 6 -init /output/workingdir/preproc/coregwf/_subject_id_sub-222_task_name_emp/coreg_pre/sub-222_task-emp_run-01_bold_roi_mcf.nii_mean_reg_flirt.mat -schedule /usr/share/fsl/5.0/etc/flirtsch/bbr.sch -wmseg /output/workingdir/preproc/coregwf/_subject_id_sub-222_task_name_emp/threshold/sub-222_T1w_preproc_brain_pve_2_thresh.nii.gz
# 170922-19:07:30,507 workflow INFO:
# 	 [Job finished] jobname: coreg_bbr.b1 jobid: 24
# 170922-19:07:30,510 workflow INFO:
# 	 Executing: applywarp.b1 ID: 25
# 170922-19:07:30,529 workflow INFO:
# 	 Executing: applywarp_mean.b1 ID: 29
# 170922-19:07:30,532 workflow INFO:
# 	 Executing node applywarp.b1 in dir: /output/workingdir/preproc/coregwf/_subject_id_sub-256_task_name_emp/applywarp
# 170922-19:07:30,563 workflow INFO:
# 	 Executing node applywarp_mean.b1 in dir: /output/workingdir/preproc/coregwf/_subject_id_sub-256_task_name_emp/applywarp_mean
# 170922-19:07:30,594 workflow INFO:
# 	 Running: flirt -in /output/workingdir/preproc/_subject_id_sub-256_task_name_emp/slicetimer/sub-256_task-emp_run-01_bold_roi_mcf_st.nii -ref /output/workingdir/preproc/coregwf/_subject_id_sub-256_task_name_emp/bet_anat/sub-256_T1w_preproc_brain.nii.gz -out sub-256_task-emp_run-01_bold_roi_mcf_st_flirt.nii -omat sub-256_task-emp_run-01_bold_roi_mcf_st_flirt.mat -applyisoxfm 4.000000 -init /output/workingdir/preproc/coregwf/_subject_id_sub-256_task_name_emp/coreg_bbr/sub-256_task-emp_run-01_bold_roi_mcf.nii_mean_reg_flirt.mat -interp spline
# 170922-19:07:30,622 workflow INFO:
# 	 Running: flirt -in /output/workingdir/preproc/_subject_id_sub-256_task_name_emp/mcflirt/sub-256_task-emp_run-01_bold_roi_mcf.nii_mean_reg.nii -ref /output/workingdir/preproc/coregwf/_subject_id_sub-256_task_name_emp/bet_anat/sub-256_T1w_preproc_brain.nii.gz -out sub-256_task-emp_run-01_bold_roi_mcf.nii_mean_reg_flirt.nii.gz -omat sub-256_task-emp_run-01_bold_roi_mcf.nii_mean_reg_flirt.mat -applyisoxfm 4.000000 -init /output/workingdir/preproc/coregwf/_subject_id_sub-256_task_name_emp/coreg_bbr/sub-256_task-emp_run-01_bold_roi_mcf.nii_mean_reg_flirt.mat -interp spline
# 170922-19:07:35,585 workflow INFO:
# 	 [Job finished] jobname: applywarp_mean.b1 jobid: 29
# 170922-19:07:46,360 workflow INFO:
# 	 [Job finished] jobname: coreg_bbr.b2 jobid: 8
# 170922-19:07:46,363 workflow INFO:
# 	 Executing: applywarp.b2 ID: 9
# 170922-19:07:46,400 workflow INFO:
# 	 Executing: applywarp_mean.b2 ID: 13
# 170922-19:07:46,402 workflow INFO:
# 	 Executing node applywarp.b2 in dir: /output/workingdir/preproc/coregwf/_subject_id_sub-270_task_name_emp/applywarp
# 170922-19:07:46,449 workflow INFO:
# 	 Running: flirt -in /output/workingdir/preproc/_subject_id_sub-270_task_name_emp/slicetimer/sub-270_task-emp_run-01_bold_roi_mcf_st.nii -ref /output/workingdir/preproc/coregwf/_subject_id_sub-270_task_name_emp/bet_anat/sub-270_T1w_preproc_brain.nii.gz -out sub-270_task-emp_run-01_bold_roi_mcf_st_flirt.nii -omat sub-270_task-emp_run-01_bold_roi_mcf_st_flirt.mat -applyisoxfm 4.000000 -init /output/workingdir/preproc/coregwf/_subject_id_sub-270_task_name_emp/coreg_bbr/sub-270_task-emp_run-01_bold_roi_mcf.nii_mean_reg_flirt.mat -interp spline170922-19:07:46,447 workflow INFO:
# 	 Executing node applywarp_mean.b2 in dir: /output/workingdir/preproc/coregwf/_subject_id_sub-270_task_name_emp/applywarp_mean
#
# 170922-19:07:46,512 workflow INFO:
# 	 Running: flirt -in /output/workingdir/preproc/_subject_id_sub-270_task_name_emp/mcflirt/sub-270_task-emp_run-01_bold_roi_mcf.nii_mean_reg.nii -ref /output/workingdir/preproc/coregwf/_subject_id_sub-270_task_name_emp/bet_anat/sub-270_T1w_preproc_brain.nii.gz -out sub-270_task-emp_run-01_bold_roi_mcf.nii_mean_reg_flirt.nii.gz -omat sub-270_task-emp_run-01_bold_roi_mcf.nii_mean_reg_flirt.mat -applyisoxfm 4.000000 -init /output/workingdir/preproc/coregwf/_subject_id_sub-270_task_name_emp/coreg_bbr/sub-270_task-emp_run-01_bold_roi_mcf.nii_mean_reg_flirt.mat -interp spline
# 170922-19:07:51,136 workflow INFO:
# 	 [Job finished] jobname: applywarp_mean.b2 jobid: 13
# 170922-19:08:04,203 workflow INFO:
# 	 [Job finished] jobname: applywarp.b1 jobid: 25
# 170922-19:08:04,206 workflow INFO:
# 	 Executing: art.b1 ID: 26
# 170922-19:08:04,233 workflow INFO:
# 	 Executing: smooth.aI.a0.b1 ID: 27
# 170922-19:08:04,237 workflow INFO:
# 	 Executing node art.b1 in dir: /output/workingdir/preproc/_subject_id_sub-256_task_name_emp/art
# 170922-19:08:04,260 workflow INFO:
# 	 Executing node smooth.aI.a0.b1 in dir: /output/workingdir/preproc/_subject_id_sub-256_task_name_emp/_fwhm_4/smooth
# 170922-19:08:04,373 interface INFO:
# 	 not intersect_mask is True
# /opt/conda/envs/neuro/lib/python3.6/site-packages/matplotlib/__init__.py:1405: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
#   warnings.warn(_use_error_msg)
# 170922-19:08:10,536 workflow INFO:
# 	 [Job finished] jobname: art.b1 jobid: 26
# 170922-19:08:10,539 workflow INFO:
# 	 Executing: smooth.aI.a1.b1 ID: 28
# 170922-19:08:10,553 workflow INFO:
# 	 Executing node smooth.aI.a1.b1 in dir: /output/workingdir/preproc/_subject_id_sub-256_task_name_emp/_fwhm_8/smooth
# 170922-19:08:22,403 workflow INFO:
# 	 [Job finished] jobname: applywarp.b2 jobid: 9
# 170922-19:08:22,407 workflow INFO:
# 	 Executing: art.b2 ID: 10
# 170922-19:08:22,462 workflow INFO:
# 	 Executing node art.b2 in dir: /output/workingdir/preproc/_subject_id_sub-270_task_name_emp/art
# 170922-19:08:22,617 interface INFO:
# 	 not intersect_mask is True
# /opt/conda/envs/neuro/lib/python3.6/site-packages/matplotlib/__init__.py:1405: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
#   warnings.warn(_use_error_msg)
# 170922-19:08:28,804 workflow INFO:
# 	 [Job finished] jobname: art.b2 jobid: 10
# 170922-19:08:28,811 workflow INFO:
# 	 Executing: smooth.aI.a0.b2 ID: 11
# 170922-19:08:28,835 workflow INFO:
# 	 Executing node smooth.aI.a0.b2 in dir: /output/workingdir/preproc/_subject_id_sub-270_task_name_emp/_fwhm_4/smooth
# 170922-19:10:36,667 workflow INFO:
# 	 [Job finished] jobname: smooth.aI.a0.b1 jobid: 27
# 170922-19:10:36,670 workflow INFO:
# 	 Executing: smooth.aI.a1.b2 ID: 12
# 170922-19:10:36,699 workflow INFO:
# 	 Executing node smooth.aI.a1.b2 in dir: /output/workingdir/preproc/_subject_id_sub-270_task_name_emp/_fwhm_8/smooth
# 170922-19:10:53,250 workflow INFO:
# 	 [Job finished] jobname: smooth.aI.a1.b1 jobid: 28
# 170922-19:10:53,255 workflow INFO:
# 	 Executing: datasink.a0.b1 ID: 30
# 170922-19:10:53,370 workflow INFO:
# 	 Executing node datasink.a0.b1 in dir: /output/workingdir/preproc/_subject_id_sub-256_task_name_emp/_fwhm_4/datasink
# 170922-19:10:53,452 interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_sub-256_task_name_emp/sub-256_task-emp_run-01_bold_roi_mcf.nii.par -> /output/datasink/preproc/sub-256/task-emp/sub-256_task-emp_run-01_bold.par
# 170922-19:10:53,494 interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_sub-256_task_name_emp/art.sub-256_task-emp_run-01_bold_roi_mcf_st_flirt_outliers.txt -> /output/datasink/preproc/sub-256/task-emp/art.sub-256_task-emp_run-01_bold_outliers.txt
# 170922-19:10:53,539 interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_sub-256_task_name_emp/plot.sub-256_task-emp_run-01_bold_roi_mcf_st_flirt.svg -> /output/datasink/preproc/sub-256/task-emp/plot.sub-256_task-emp_run-01_bold.svg
# 170922-19:10:53,579 interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_sub-256_task_name_emp/_fwhm_4/ssub-256_task-emp_run-01_bold_roi_mcf_st_flirt.nii -> /output/datasink/preproc/sub-256/task-emp/fwhm-4_ssub-256_task-emp_run-01_bold.nii
# 170922-19:10:53,621 interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_sub-256_task_name_emp/sub-256_task-emp_run-01_bold_roi_mcf.nii_mean_reg_flirt.mat -> /output/datasink/preproc/sub-256/task-emp/sub-256_task-emp_run-01_bold_mean.mat
# 170922-19:10:53,658 interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_sub-256_task_name_emp/sub-256_task-emp_run-01_bold_roi_mcf.nii_mean_reg_flirt.nii.gz -> /output/datasink/preproc/sub-256/task-emp/sub-256_task-emp_run-01_bold_mean.nii.gz
# 170922-19:10:53,694 interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_sub-256_task_name_emp/sub-256_T1w_preproc_brain.nii.gz -> /output/datasink/preproc/sub-256/task-emp/sub-256_T1w_preproc_brain.nii.gz
# 170922-19:10:53,766 workflow INFO:
# 	 [Job finished] jobname: datasink.a0.b1 jobid: 30
# 170922-19:10:53,772 workflow INFO:
# 	 Executing: datasink.a1.b1 ID: 31
# 170922-19:10:53,891 workflow INFO:
# 	 Executing node datasink.a1.b1 in dir: /output/workingdir/preproc/_subject_id_sub-256_task_name_emp/_fwhm_8/datasink
# 170922-19:10:53,993 interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_sub-256_task_name_emp/sub-256_task-emp_run-01_bold_roi_mcf.nii.par -> /output/datasink/preproc/sub-256/task-emp/sub-256_task-emp_run-01_bold.par
# 170922-19:10:54,35 interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_sub-256_task_name_emp/art.sub-256_task-emp_run-01_bold_roi_mcf_st_flirt_outliers.txt -> /output/datasink/preproc/sub-256/task-emp/art.sub-256_task-emp_run-01_bold_outliers.txt
# 170922-19:10:54,58 interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_sub-256_task_name_emp/plot.sub-256_task-emp_run-01_bold_roi_mcf_st_flirt.svg -> /output/datasink/preproc/sub-256/task-emp/plot.sub-256_task-emp_run-01_bold.svg
# 170922-19:10:54,84 interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_sub-256_task_name_emp/_fwhm_8/ssub-256_task-emp_run-01_bold_roi_mcf_st_flirt.nii -> /output/datasink/preproc/sub-256/task-emp/fwhm-8_ssub-256_task-emp_run-01_bold.nii
# 170922-19:10:54,119 interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_sub-256_task_name_emp/sub-256_task-emp_run-01_bold_roi_mcf.nii_mean_reg_flirt.mat -> /output/datasink/preproc/sub-256/task-emp/sub-256_task-emp_run-01_bold_mean.mat
# 170922-19:10:54,150 interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_sub-256_task_name_emp/sub-256_task-emp_run-01_bold_roi_mcf.nii_mean_reg_flirt.nii.gz -> /output/datasink/preproc/sub-256/task-emp/sub-256_task-emp_run-01_bold_mean.nii.gz
# 170922-19:10:54,187 interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_sub-256_task_name_emp/sub-256_T1w_preproc_brain.nii.gz -> /output/datasink/preproc/sub-256/task-emp/sub-256_T1w_preproc_brain.nii.gz
# 170922-19:10:54,258 workflow INFO:
# 	 [Job finished] jobname: datasink.a1.b1 jobid: 31
# 170922-19:11:13,457 workflow INFO:
# 	 [Job finished] jobname: smooth.aI.a0.b2 jobid: 11
# 170922-19:11:13,462 workflow INFO:
# 	 Executing: datasink.a0.b2 ID: 14
# 170922-19:11:13,516 workflow INFO:
# 	 Executing node datasink.a0.b2 in dir: /output/workingdir/preproc/_subject_id_sub-270_task_name_emp/_fwhm_4/datasink
# 170922-19:11:13,579 interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_sub-270_task_name_emp/sub-270_task-emp_run-01_bold_roi_mcf.nii.par -> /output/datasink/preproc/sub-270/task-emp/sub-270_task-emp_run-01_bold.par
# 170922-19:11:13,609 interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_sub-270_task_name_emp/art.sub-270_task-emp_run-01_bold_roi_mcf_st_flirt_outliers.txt -> /output/datasink/preproc/sub-270/task-emp/art.sub-270_task-emp_run-01_bold_outliers.txt
# 170922-19:11:13,638 interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_sub-270_task_name_emp/plot.sub-270_task-emp_run-01_bold_roi_mcf_st_flirt.svg -> /output/datasink/preproc/sub-270/task-emp/plot.sub-270_task-emp_run-01_bold.svg
# 170922-19:11:13,669 interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_sub-270_task_name_emp/_fwhm_4/ssub-270_task-emp_run-01_bold_roi_mcf_st_flirt.nii -> /output/datasink/preproc/sub-270/task-emp/fwhm-4_ssub-270_task-emp_run-01_bold.nii
# 170922-19:11:13,706 interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_sub-270_task_name_emp/sub-270_task-emp_run-01_bold_roi_mcf.nii_mean_reg_flirt.mat -> /output/datasink/preproc/sub-270/task-emp/sub-270_task-emp_run-01_bold_mean.mat
# 170922-19:11:13,736 interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_sub-270_task_name_emp/sub-270_task-emp_run-01_bold_roi_mcf.nii_mean_reg_flirt.nii.gz -> /output/datasink/preproc/sub-270/task-emp/sub-270_task-emp_run-01_bold_mean.nii.gz
# 170922-19:11:13,770 interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_sub-270_task_name_emp/sub-270_T1w_preproc_brain.nii.gz -> /output/datasink/preproc/sub-270/task-emp/sub-270_T1w_preproc_brain.nii.gz
# 170922-19:11:13,832 workflow INFO:
# 	 [Job finished] jobname: datasink.a0.b2 jobid: 14
# 170922-19:11:25,802 workflow INFO:
# 	 [Job finished] jobname: coreg_bbr.b0 jobid: 40
# 170922-19:11:25,805 workflow INFO:
# 	 Executing: applywarp.b0 ID: 41
# 170922-19:11:25,833 workflow INFO:
# 	 Executing: applywarp_mean.b0 ID: 45
# 170922-19:11:25,836 workflow INFO:
# 	 Executing node applywarp.b0 in dir: /output/workingdir/preproc/coregwf/_subject_id_sub-222_task_name_emp/applywarp
# 170922-19:11:25,859 workflow INFO:
# 	 Executing node applywarp_mean.b0 in dir: /output/workingdir/preproc/coregwf/_subject_id_sub-222_task_name_emp/applywarp_mean
# 170922-19:11:25,885 workflow INFO:
# 	 Running: flirt -in /output/workingdir/preproc/_subject_id_sub-222_task_name_emp/mcflirt/sub-222_task-emp_run-01_bold_roi_mcf.nii_mean_reg.nii -ref /output/workingdir/preproc/coregwf/_subject_id_sub-222_task_name_emp/bet_anat/sub-222_T1w_preproc_brain.nii.gz -out sub-222_task-emp_run-01_bold_roi_mcf.nii_mean_reg_flirt.nii.gz -omat sub-222_task-emp_run-01_bold_roi_mcf.nii_mean_reg_flirt.mat -applyisoxfm 4.000000 -init /output/workingdir/preproc/coregwf/_subject_id_sub-222_task_name_emp/coreg_bbr/sub-222_task-emp_run-01_bold_roi_mcf.nii_mean_reg_flirt.mat -interp spline
# 170922-19:11:25,886 workflow INFO:
# 	 Running: flirt -in /output/workingdir/preproc/_subject_id_sub-222_task_name_emp/slicetimer/sub-222_task-emp_run-01_bold_roi_mcf_st.nii -ref /output/workingdir/preproc/coregwf/_subject_id_sub-222_task_name_emp/bet_anat/sub-222_T1w_preproc_brain.nii.gz -out sub-222_task-emp_run-01_bold_roi_mcf_st_flirt.nii -omat sub-222_task-emp_run-01_bold_roi_mcf_st_flirt.mat -applyisoxfm 4.000000 -init /output/workingdir/preproc/coregwf/_subject_id_sub-222_task_name_emp/coreg_bbr/sub-222_task-emp_run-01_bold_roi_mcf.nii_mean_reg_flirt.mat -interp spline
# 170922-19:11:30,397 workflow INFO:
# 	 [Job finished] jobname: applywarp_mean.b0 jobid: 45
# 170922-19:11:59,25 workflow INFO:
# 	 [Job finished] jobname: applywarp.b0 jobid: 41
# 170922-19:11:59,28 workflow INFO:
# 	 Executing: art.b0 ID: 42
# 170922-19:11:59,51 workflow INFO:
# 	 Executing: smooth.aI.a0.b0 ID: 43
# 170922-19:11:59,53 workflow INFO:
# 	 Executing node art.b0 in dir: /output/workingdir/preproc/_subject_id_sub-222_task_name_emp/art
# 170922-19:11:59,71 workflow INFO:
# 	 Executing node smooth.aI.a0.b0 in dir: /output/workingdir/preproc/_subject_id_sub-222_task_name_emp/_fwhm_4/smooth170922-19:11:59,69 workflow INFO:
# 	 Executing: smooth.aI.a1.b0 ID: 44
#
# 170922-19:11:59,95 workflow INFO:
# 	 Executing node smooth.aI.a1.b0 in dir: /output/workingdir/preproc/_subject_id_sub-222_task_name_emp/_fwhm_8/smooth
# 170922-19:11:59,159 interface INFO:
# 	 not intersect_mask is True
# /opt/conda/envs/neuro/lib/python3.6/site-packages/matplotlib/__init__.py:1405: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
#   warnings.warn(_use_error_msg)
# 170922-19:12:07,136 workflow INFO:
# 	 [Job finished] jobname: art.b0 jobid: 42
# 170922-19:12:27,973 workflow INFO:
# 	 [Job finished] jobname: smooth.aI.a1.b2 jobid: 12
# 170922-19:12:27,977 workflow INFO:
# 	 Executing: datasink.a1.b2 ID: 15
# 170922-19:12:28,44 workflow INFO:
# 	 Executing node datasink.a1.b2 in dir: /output/workingdir/preproc/_subject_id_sub-270_task_name_emp/_fwhm_8/datasink
# 170922-19:12:28,93 interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_sub-270_task_name_emp/sub-270_task-emp_run-01_bold_roi_mcf.nii.par -> /output/datasink/preproc/sub-270/task-emp/sub-270_task-emp_run-01_bold.par
# 170922-19:12:28,107 interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_sub-270_task_name_emp/art.sub-270_task-emp_run-01_bold_roi_mcf_st_flirt_outliers.txt -> /output/datasink/preproc/sub-270/task-emp/art.sub-270_task-emp_run-01_bold_outliers.txt
# 170922-19:12:28,119 interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_sub-270_task_name_emp/plot.sub-270_task-emp_run-01_bold_roi_mcf_st_flirt.svg -> /output/datasink/preproc/sub-270/task-emp/plot.sub-270_task-emp_run-01_bold.svg
# 170922-19:12:28,133 interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_sub-270_task_name_emp/_fwhm_8/ssub-270_task-emp_run-01_bold_roi_mcf_st_flirt.nii -> /output/datasink/preproc/sub-270/task-emp/fwhm-8_ssub-270_task-emp_run-01_bold.nii
# 170922-19:12:28,148 interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_sub-270_task_name_emp/sub-270_task-emp_run-01_bold_roi_mcf.nii_mean_reg_flirt.mat -> /output/datasink/preproc/sub-270/task-emp/sub-270_task-emp_run-01_bold_mean.mat
# 170922-19:12:28,162 interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_sub-270_task_name_emp/sub-270_task-emp_run-01_bold_roi_mcf.nii_mean_reg_flirt.nii.gz -> /output/datasink/preproc/sub-270/task-emp/sub-270_task-emp_run-01_bold_mean.nii.gz
# 170922-19:12:28,175 interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_sub-270_task_name_emp/sub-270_T1w_preproc_brain.nii.gz -> /output/datasink/preproc/sub-270/task-emp/sub-270_T1w_preproc_brain.nii.gz
# 170922-19:12:28,226 workflow INFO:
# 	 [Job finished] jobname: datasink.a1.b2 jobid: 15
# 170922-19:13:54,456 workflow INFO:
# 	 [Job finished] jobname: smooth.aI.a1.b0 jobid: 44
# 170922-19:13:54,461 workflow INFO:
# 	 Executing: datasink.a1.b0 ID: 47
# 170922-19:13:54,529 workflow INFO:
# 	 Executing node datasink.a1.b0 in dir: /output/workingdir/preproc/_subject_id_sub-222_task_name_emp/_fwhm_8/datasink
# 170922-19:13:54,582 interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_sub-222_task_name_emp/sub-222_task-emp_run-01_bold_roi_mcf.nii.par -> /output/datasink/preproc/sub-222/task-emp/sub-222_task-emp_run-01_bold.par
# 170922-19:13:54,614 interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_sub-222_task_name_emp/art.sub-222_task-emp_run-01_bold_roi_mcf_st_flirt_outliers.txt -> /output/datasink/preproc/sub-222/task-emp/art.sub-222_task-emp_run-01_bold_outliers.txt
# 170922-19:13:54,625 interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_sub-222_task_name_emp/plot.sub-222_task-emp_run-01_bold_roi_mcf_st_flirt.svg -> /output/datasink/preproc/sub-222/task-emp/plot.sub-222_task-emp_run-01_bold.svg
# 170922-19:13:54,645 interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_sub-222_task_name_emp/_fwhm_8/ssub-222_task-emp_run-01_bold_roi_mcf_st_flirt.nii -> /output/datasink/preproc/sub-222/task-emp/fwhm-8_ssub-222_task-emp_run-01_bold.nii
# 170922-19:13:54,685 interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_sub-222_task_name_emp/sub-222_task-emp_run-01_bold_roi_mcf.nii_mean_reg_flirt.mat -> /output/datasink/preproc/sub-222/task-emp/sub-222_task-emp_run-01_bold_mean.mat
# 170922-19:13:54,696 interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_sub-222_task_name_emp/sub-222_task-emp_run-01_bold_roi_mcf.nii_mean_reg_flirt.nii.gz -> /output/datasink/preproc/sub-222/task-emp/sub-222_task-emp_run-01_bold_mean.nii.gz
# 170922-19:13:54,707 interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_sub-222_task_name_emp/sub-222_T1w_preproc_brain.nii.gz -> /output/datasink/preproc/sub-222/task-emp/sub-222_T1w_preproc_brain.nii.gz
# 170922-19:13:54,793 workflow INFO:
# 	 [Job finished] jobname: datasink.a1.b0 jobid: 47
# 170922-19:13:54,819 workflow INFO:
# 	 [Job finished] jobname: smooth.aI.a0.b0 jobid: 43
# 170922-19:13:54,830 workflow INFO:
# 	 Executing: datasink.a0.b0 ID: 46
# 170922-19:13:54,886 workflow INFO:
# 	 Executing node datasink.a0.b0 in dir: /output/workingdir/preproc/_subject_id_sub-222_task_name_emp/_fwhm_4/datasink
# 170922-19:13:54,926 interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_sub-222_task_name_emp/sub-222_task-emp_run-01_bold_roi_mcf.nii.par -> /output/datasink/preproc/sub-222/task-emp/sub-222_task-emp_run-01_bold.par
# 170922-19:13:54,940 interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_sub-222_task_name_emp/art.sub-222_task-emp_run-01_bold_roi_mcf_st_flirt_outliers.txt -> /output/datasink/preproc/sub-222/task-emp/art.sub-222_task-emp_run-01_bold_outliers.txt
# 170922-19:13:54,952 interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_sub-222_task_name_emp/plot.sub-222_task-emp_run-01_bold_roi_mcf_st_flirt.svg -> /output/datasink/preproc/sub-222/task-emp/plot.sub-222_task-emp_run-01_bold.svg
# 170922-19:13:54,964 interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_sub-222_task_name_emp/_fwhm_4/ssub-222_task-emp_run-01_bold_roi_mcf_st_flirt.nii -> /output/datasink/preproc/sub-222/task-emp/fwhm-4_ssub-222_task-emp_run-01_bold.nii
# 170922-19:13:54,976 interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_sub-222_task_name_emp/sub-222_task-emp_run-01_bold_roi_mcf.nii_mean_reg_flirt.mat -> /output/datasink/preproc/sub-222/task-emp/sub-222_task-emp_run-01_bold_mean.mat
# 170922-19:13:54,985 interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_sub-222_task_name_emp/sub-222_task-emp_run-01_bold_roi_mcf.nii_mean_reg_flirt.nii.gz -> /output/datasink/preproc/sub-222/task-emp/sub-222_task-emp_run-01_bold_mean.nii.gz
# 170922-19:13:55,0 interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_sub-222_task_name_emp/sub-222_T1w_preproc_brain.nii.gz -> /output/datasink/preproc/sub-222/task-emp/sub-222_T1w_preproc_brain.nii.gz
# 170922-19:13:55,44 workflow INFO:
# 	 [Job finished] jobname: datasink.a0.b0 jobid: 46

# %% [markdown]
# ## Inspect output
#
# Let's check the structure of the output folder, to see if we have everything we wanted to save.

# %%
# !tree /output/datasink/preproc
# Out:
# /output/datasink/preproc
# |-- sub-222
# |   `-- task-emp
# |       |-- art.sub-222_task-emp_run-01_bold_outliers.txt
# |       |-- fwhm-4_ssub-222_task-emp_run-01_bold.nii
# |       |-- fwhm-8_ssub-222_task-emp_run-01_bold.nii
# |       |-- plot.sub-222_task-emp_run-01_bold.svg
# |       |-- sub-222_T1w_preproc_brain.nii.gz
# |       |-- sub-222_task-emp_run-01_bold.par
# |       |-- sub-222_task-emp_run-01_bold_mean.mat
# |       `-- sub-222_task-emp_run-01_bold_mean.nii.gz
# |-- sub-256
# |   `-- task-emp
# |       |-- art.sub-256_task-emp_run-01_bold_outliers.txt
# |       |-- fwhm-4_ssub-256_task-emp_run-01_bold.nii
# |       |-- fwhm-8_ssub-256_task-emp_run-01_bold.nii
# |       |-- plot.sub-256_task-emp_run-01_bold.svg
# |       |-- sub-256_T1w_preproc_brain.nii.gz
# |       |-- sub-256_task-emp_run-01_bold.par
# |       |-- sub-256_task-emp_run-01_bold_mean.mat
# |       `-- sub-256_task-emp_run-01_bold_mean.nii.gz
# `-- sub-270
#     `-- task-emp
#         |-- art.sub-270_task-emp_run-01_bold_outliers.txt
#         |-- fwhm-4_ssub-270_task-emp_run-01_bold.nii
#         |-- fwhm-8_ssub-270_task-emp_run-01_bold.nii
#         |-- plot.sub-270_task-emp_run-01_bold.svg
#         |-- sub-270_T1w_preproc_brain.nii.gz
#         |-- sub-270_task-emp_run-01_bold.par
#         |-- sub-270_task-emp_run-01_bold_mean.mat
#         `-- sub-270_task-emp_run-01_bold_mean.nii.gz
#
# 6 directories, 24 files

# %% [markdown]
# ## Visualize results
#
# Let's check the effect of the different smoothing kernels.

# %%
from nilearn import image, plotting
plotting.plot_epi(
    '/data/derivatives/fmriprep/sub-222/anat/sub-222_T1w_preproc.nii.gz',
    title="T1", display_mode='ortho', annotate=False, draw_cross=False, cmap='gray')

out_path = '/output/datasink/preproc/sub-222/task-emp'
plotting.plot_epi(opj(out_path, 'sub-222_task-emp_run-01_bold_mean.nii.gz'),
                  title="fwhm = 0mm", display_mode='ortho', annotate=False, draw_cross=False, cmap='gray')

plotting.plot_epi(image.mean_img(opj(out_path, 'fwhm-4_ssub-222_task-emp_run-01_bold.nii')),
                  title="fwhm = 4mm", display_mode='ortho', annotate=False, draw_cross=False, cmap='gray')

plotting.plot_epi(image.mean_img(opj(out_path, 'fwhm-8_ssub-222_task-emp_run-01_bold.nii')),
                  title="fwhm = 8mm", display_mode='ortho', annotate=False, draw_cross=False, cmap='gray')
# Out:
# /opt/conda/envs/neuro/lib/python3.6/site-packages/matplotlib/__init__.py:1405: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
#   warnings.warn(_use_error_msg)

# %% [markdown]
# Now, let's investigate the motion parameters. How much did the subject move and turn in the scanner?

# %%
import numpy as np
import pylab as plt



subject_list = ['sub-222', 'sub-256', 'sub-270']

for subject in subject_list:
    par = np.loadtxt('/output/datasink/preproc/'+ subject + '/task-emp/' + subject +'_task-emp_run-01_bold.par')
    fig, axes = plt.subplots(2, 1, figsize=(15, 5))
    axes[0].set_ylabel('rotation (radians)')
    axes[0].plot(par[0:, :3])
    axes[1].plot(par[0:, 3:])
    axes[1].set_xlabel('time (TR)')
    axes[1].set_ylabel('translation (mm)')

# %% [markdown]
# There seems to be a rather drastic motion around volume 102. Let's check if the outliers detection algorithm was able to pick this up.

# %%
import numpy as np



subject_list = ['sub-222', 'sub-256', 'sub-270']

subject= 'sub-270'
outlier_ids = np.loadtxt('/output/datasink/preproc/' + subject + '/task-emp/art.' + subject + '_task-emp_run-01_bold_outliers.txt')
print('Outliers were detected at volumes: %s' % outlier_ids)

from IPython.display import SVG
SVG(filename='/output/datasink/preproc/' + subject + '/task-emp/plot.' +subject + '_task-emp_run-01_bold.svg')
# Out:
# Outliers were detected at volumes: 65.0
